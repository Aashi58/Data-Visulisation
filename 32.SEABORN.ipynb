# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='dark')

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=4,aspect=3)

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=4,aspect=3,hue='sex')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=6,aspect=2,hue='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=5,aspect=2,hue='sex',style='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=5,aspect=2,hue='smoker',style='time',size='size')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=5,aspect=1,hue='smoker',col='sex')

# %%
#SCATTER PLOT
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex',size='size',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#COUNT PLOT

sns.countplot(x=tips['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(x='day',y='total_bill',data=tips,height=5,aspect=2.5)

# %%
sns.catplot(x='day',y='total_bill',data=tips,height=5,aspect=2.5,hue='sex')

# %%
diamond=sns.load_dataset('diamonds')
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
sns.catplot(x='cut',y='price',data=diamond,height=5,aspect=2.5,kind='box')

# %%
sns.catplot(y='total_bill',x='day',hue='sex',data=tips,height=5,aspect=2.5,kind='violin')

# %%
df=pd.read_excel('Sample - Superstore Sales (Excel).xls')
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
plt.scatter(df.Sales,df.Profit)
plt.xlabel('Sales')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.relplot(x='Sales',y='Profit',data=df)
plt.show()

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1768
# Low              1720
# Not Specified    1672
# Medium           1631
# Critical         1608
# Name: count, dtype: int64

# %%
sns.relplot(x='Sales',y='Profit',data=df,hue='Order Priority')
plt.show()

# %%
sns.relplot(x='Sales',y='Profit',data=df,hue='Order Priority',style='Ship Mode')
plt.show()

# %%
df['Year']=df['Order Date'].dt.year
df.Year.head()
# Out:
# 0    2010
# 1    2012
# 2    2012
# 3    2011
# 4    2010
# Name: Year, dtype: int32

# %%
df.shape
# Out:
# (8399, 22)

# %%
sns.relplot(x='Year',y='Sales',data=df,kind='line')

# %%
sns.relplot(x='Year',y='Sales',data=df,kind='line',ci=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df.query('Profit>1000'),jitter=False)

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df.query('Profit>1000 & Profit <5000' ),kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 20.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 20.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 19.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=df,kind='box')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=df,kind='box',hue='Ship Mode')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=df,kind='box',col='Ship Mode')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=df,kind='violin',col='Ship Mode',row='Customer Segment')

# %%
sns.catplot(x='Product Category',y='Sales',data=df,kind='point')

# %%
sns.catplot(x='Product Category',y='Sales',data=df,kind='point',hue='Ship Mode',col='Ship Mode',row='Customer Segment')

# %%
sns.distplot(df.Sales,kde=False)
# Out:
# <ipython-input-45-1f5dbe331bc7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Sales,kde=False)
# <Axes: xlabel='Sales'>

# %%
sns.distplot(df.Profit)
# Out:
# <ipython-input-46-c0e8a8449a7b>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit)
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df.Profit,hist=False)
# Out:
# <ipython-input-48-bf3ce02e6d4d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit,hist=False)
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df.Profit,kde=False,rug=True)
# Out:
# <ipython-input-49-ed460d27f94d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit,kde=False,rug=True)
# <Axes: xlabel='Profit'>

# %%
sns.distplot(df.Profit[(df.Region=='West')&(df.Profit>100)],kde=False,rug=True,bins=100)
# Out:
# <ipython-input-50-b997fb4a0f24>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit[(df.Region=='West')&(df.Profit>100)],kde=False,rug=True,bins=100)
# <Axes: xlabel='Profit'>

# %%
# pandas profilling give a report

pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:363: UserWarning: Try running command: 'pip install --upgrade Pillow' to avoid ValueError
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
