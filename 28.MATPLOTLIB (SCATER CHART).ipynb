# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('employee.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
plt.rcParams['figure.figsize'] = (9,5)

plt.scatter(data['Age'],
            data['MonthlyRate'])
plt.show()

# %%
plt.scatter(data['Age'],
            data['TotalWorkingYears'],data['MonthlyRate'],color='red')

plt.ylabel('Monthly Rate')
plt.xlabel('Total Working Years')
plt.title('compare Monthly Wages with Expeirence',frontsize=20)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-92bd0b961ea9> in <cell line: 6>()
#       4 plt.ylabel('Monthly Rate')
#       5 plt.xlabel('Total Working Years')
# ----> 6 plt.title('compare Monthly Wages with Experence',frontsize=20)
#       7 plt.show
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    3082 @_copy_docstring_and_deprecators(Axes.set_title)
#    3083 def title(label, fontdict=None, loc=None, pad=None, *, y=None, **kwargs):
# -> 3084     return gca().set_title(
#    3085         label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    3086
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     178         if fontdict is not None:
#     179             title.update(fontdict)
# ...
